# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\gm194\Downloads\Dados_1.csv', encoding= "UTF-8", sep = ",")
df.head(3)
# Out:
#            city  area  rooms  bathroom  parking spaces floor animal  \
# 0     São Paulo    70      2         1               1     7  acept
# 1     São Paulo   320      4         4               0    20  acept
# 2  Porto Alegre    80      1         1               1     6  acept
#
#        furniture  hoa (R$)  rent amount (R$)  property tax (R$)  \
# 0      furnished      2065              3300                211
# 1  not furnished      1200              4960               1750
# 2  not furnished      1000              2800                  0
#
#    fire insurance (R$)  total (R$)
# 0                   42        5618
# 1                   63        7973
# 2                   41        3841

# %% [markdown]
# ## Função Isin para filtrar dados

# %%
df['city'].unique()
df.dtypes
# Out:
# city                   object
# area                    int64
# rooms                   int64
# bathroom                int64
# parking spaces          int64
# floor                  object
# animal                 object
# furniture              object
# hoa (R$)                int64
# rent amount (R$)        int64
# property tax (R$)       int64
# fire insurance (R$)     int64
# total (R$)              int64
# dtype: object

# %%
df_filtrado = df[(df['city'].isin(['São Paulo', 'Porto Alegre'])) & (df['rooms'] > 1) & (df['floor'] == '3')
 & (df['total (R$)'] >= 3000)]

df_filtrado.head(3)
# Out:
#           city  area  rooms  bathroom  parking spaces floor     animal  \
# 8    São Paulo   152      2         2               1     3      acept
# 89   São Paulo    85      2         2               2     3  not acept
# 124  São Paulo    94      3         3               2     3      acept
#
#          furniture  hoa (R$)  rent amount (R$)  property tax (R$)  \
# 8        furnished      1000             15000                250
# 89   not furnished      1500              2800                292
# 124      furnished      1220              5010                395
#
#      fire insurance (R$)  total (R$)
# 8                    191       16440
# 89                    36        4628
# 124                   64        6689
